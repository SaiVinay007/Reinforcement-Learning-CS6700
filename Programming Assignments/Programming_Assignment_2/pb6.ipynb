# %%
import gym
import gym_pdw

import numpy as np
from matplotlib import pyplot as plt

# %%
# Part a) same as sarsa except we get the Q values using function approximation

class FA_SARSA_lambda:
    
    def update(self, curr_state, curr_action, reward, next_state, next_action, E, alpha, gamma, theta):
        feat1 = self.make_feature(curr_state, curr_action)
        feat2 = self.make_feature(next_state, next_action)
        error = reward + (gamma*(np.matmul(np.transpose(theta),feat2))) - (np.matmul(np.transpose(theta),feat1))
#         print("error", error)
        theta = theta + alpha*error*E
#         print(theta)
        return theta
    
    
    def bin_array(self, num, m):
        """Convert a positive integer num into an m-bit bit vector"""
        return np.array(list(np.binary_repr(num).zfill(m))).astype(np.int8)
    
    
    def make_feature(self, state, action):
        x,y = state
        v1 = self.bin_array(x,7)
        v2 = self.bin_array(y,11)
        v3 = np.zeros([4])
        v3[action] = 1
        f = np.concatenate((v1,v2,v3))
        return f
        
    
    def select_action(self, epsilon, state, theta, env):
        if np.random.uniform(0,1) < epsilon:
            action = env.random_action()
        else:
            Q = []
            for i in range(4):
                tmp_feat = self.make_feature(state, i)
                val = np.matmul(np.transpose(theta),tmp_feat)
                Q.append(val)
#                 print(tmp_feat, val)
#                 print(theta)
            action = np.argmax(Q)
#             print(Q, action)
        
        return action
    
        
    def fa_sarsa_lambda(self, gamma, alpha, epsilon, episodes, env, lambda_):
        
        # Making a large grid
        new_grid, goal_region = env.large_puddle_world(10, 100, 'A') 
        
        # The boundary coordinates of goal region
        x1,x2,y1,y2 = goal_region
        
        # start positions
        start_pos = env.large_start_pos(new_grid, 10, 100)
#         print(len(start_pos), len(start_pos[0]))
        
#         Q = np.zeros([22])
        Q = np.random.rand(22)
        ''' Make a function approximator '''
        # Decide what are the parameters
        # What will be the features of a state
        # Q = theta^T * Phi(s)
#         feat = make_feature()

        theta = np.random.rand(22)

        
        steps = np.zeros([episodes])
        avg_reward = np.zeros([episodes])
        
        
        
        for episode in range(episodes):
            
            E = np.zeros([22])
            
            curr_state = env.large_reset(start_pos)
            
            curr_action = self.select_action(epsilon, curr_state, Q, env)            
            
            feat = self.make_feature(curr_state, curr_action)
            
            if episode%20 ==0:
                epsilon -= 0.1
                if epsilon <0.1:
                    epsilon = 0.1
            Max_steps = 100000
            for i in range(Max_steps):
                
                E += 1
#                 print("==========")
                next_state, reward = env.large_step(new_grid, curr_state, curr_action)                
                next_action = self.select_action(epsilon, next_state, theta, env)

#                 print('reward == ', reward,"curr_state==", curr_state, "next_state==", next_state, "action =",curr_action)
#                 print("==========")
                E = gamma*lambda_*E + feat
                
                theta = self.update(curr_state, curr_action, reward, next_state, next_action, E, alpha, gamma, theta)
                
                
                curr_state = next_state
                curr_action = next_action
                
                
                steps[episode]+=1
                avg_reward[episode] += reward


                if (curr_state[0]>=x1  and curr_state[0]<x2 and 
                    curr_state[1]>=y1  and curr_state[1]<y2):
                    print("Steps =======================", steps[episode])
                    print("reward=======================", avg_reward[episode])
                    break

        return avg_reward, steps, theta
    
    def plot_fa_sarsa_lambda(self, avg_reward, steps, episodes):
        '''
        Gets the data for all curves and plots them in one graph
        '''


        # Figure instances will be returned.
        fig1=plt.figure(figsize=(10,6)).add_subplot(111)
        fig2=plt.figure(figsize=(10,6)).add_subplot(111)

        # colors for different values of epsilon
        colors = ['g', 'r', 'k', 'b', 'y','m', 'c']

        fig1.plot(range(episodes), avg_reward, colors[0], label = " Average reward " )
        fig2.plot(range(episodes), steps, colors[1], label = " Steps")

        # Labelling the plot
        fig1.title.set_text('Linear funciton approximator SARSA : Avg reward vs episodes')
        fig1.set_ylabel('Average Reward')
        fig1.set_xlabel('episodes')
        fig1.set_ylim(top = 20)
        fig1.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        # Labelling the plot
        fig2.title.set_text('Linear funciton approximator SARSA: Num steps vs episodes')
        fig2.set_ylabel('Steps')
        fig2.set_xlabel('episodes')
        fig2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        # Display the plot
        plt.show()

# %%
# To display the policy learn't
def plot_policy(goal_pos, Q):
    plt.rcParams['figure.figsize'] = [7,7]
    fig, ax = plt.subplots()

    ax.matshow(np.argmax(Q, axis=0))
    for i in range(12):
        for j in range(12):
            if [j,i] == goal_pos:
                ax.text(i,j,'$', va='center', ha='center')
            else:
                c = int(np.argmax(Q, axis=0)[j,i])
                direcs = {0:'↑', 1:'➜', 2:'←', 3:'↓' }
                ax.text(i, j, direcs[c], va='center', ha='center')

# %%
def main():    # parameters
    gamma = 1000
    alpha = 0.1
    epsilon = 0.5
    episodes = 100
    
    lambda_ = [0.1, 0.5]
    
    env = gym.make('gym_pdw:pdw-v0')
    fa = FA_SARSA_lambda()
    for i in range(len(lambda_)):
        avg_reward, steps, theta = fa.fa_sarsa_lambda(gamma, alpha, epsilon, episodes, env, lambda_[i])
        fa.plot_fa_sarsa_lambda(avg_reward, steps, episodes)
#     plot_policy(goal_pos,Q)    

main()
# Out:
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in multiply
#   # Remove the CWD from sys.path while we load stuff.
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in matmul
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in matmul
#
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:99: RuntimeWarning: overflow encountered in multiply
# Steps ======================= 4389.0
# reward======================= 10.0
# Steps ======================= 4378.0
# reward======================= 10.0
# Steps ======================= 4205.0
# reward======================= 10.0
# Steps ======================= 4497.0
# reward======================= 10.0
# Steps ======================= 4025.0
# reward======================= 10.0
# Steps ======================= 3793.0
# reward======================= 10.0
# Steps ======================= 3991.0
# reward======================= 10.0
# Steps ======================= 3923.0
# reward======================= 10.0
# Steps ======================= 4246.0
# reward======================= 10.0
# Steps ======================= 4400.0
# reward======================= 10.0
# Steps ======================= 4585.0
# reward======================= 10.0
# Steps ======================= 4074.0
# reward======================= 10.0
# Steps ======================= 4364.0
# reward======================= 10.0
# Steps ======================= 3880.0
# reward======================= 10.0
# Steps ======================= 3935.0
# reward======================= 10.0
# Steps ======================= 3942.0
# reward======================= 10.0
# Steps ======================= 3963.0
# reward======================= 10.0
# Steps ======================= 3903.0
# reward======================= 10.0
# Steps ======================= 4286.0
# reward======================= 10.0
# Steps ======================= 4063.0
# reward======================= 10.0
# Steps ======================= 4871.0
# reward======================= 10.0
# Steps ======================= 5142.0
# reward======================= 10.0
# Steps ======================= 5174.0
# reward======================= 10.0
# Steps ======================= 4729.0
# reward======================= 10.0
# Steps ======================= 4887.0
# reward======================= 10.0
# Steps ======================= 4793.0
# reward======================= 10.0
# Steps ======================= 5431.0
# reward======================= 10.0
# Steps ======================= 5299.0
# reward======================= 10.0
# Steps ======================= 5198.0
# reward======================= 10.0
# Steps ======================= 5219.0
# reward======================= 10.0
# Steps ======================= 4677.0
# reward======================= 10.0
# Steps ======================= 4821.0
# reward======================= 10.0
# Steps ======================= 5102.0
# reward======================= 10.0
# Steps ======================= 5021.0
# reward======================= 10.0
# Steps ======================= 4542.0
# reward======================= 10.0
# Steps ======================= 4898.0
# reward======================= 10.0
# Steps ======================= 4895.0
# reward======================= 10.0
# Steps ======================= 5253.0
# reward======================= 10.0
# Steps ======================= 4931.0
# reward======================= 10.0
# Steps ======================= 4639.0
# reward======================= 10.0
# Steps ======================= 6097.0
# reward======================= 10.0
# Steps ======================= 6323.0
# reward======================= 10.0
# Steps ======================= 6778.0
# reward======================= 10.0
# Steps ======================= 6903.0
# reward======================= 10.0
# Steps ======================= 6592.0
# reward======================= 10.0
# Steps ======================= 6713.0
# reward======================= 10.0
# Steps ======================= 6215.0
# reward======================= 10.0
# Steps ======================= 5917.0
# reward======================= 10.0
# Steps ======================= 5737.0
# reward======================= 10.0
# Steps ======================= 6840.0
# reward======================= 10.0
# Steps ======================= 6533.0
# reward======================= 10.0
# Steps ======================= 6138.0
# reward======================= 10.0
# Steps ======================= 6877.0
# reward======================= 10.0
# Steps ======================= 6950.0
# reward======================= 10.0
# Steps ======================= 6714.0
# reward======================= 10.0
# Steps ======================= 6731.0
# reward======================= 10.0
# Steps ======================= 7046.0
# reward======================= 10.0
# Steps ======================= 6636.0
# reward======================= 10.0
# Steps ======================= 6017.0
# reward======================= 10.0
# Steps ======================= 7277.0
# reward======================= 10.0
# Steps ======================= 9543.0
# reward======================= 10.0
# Steps ======================= 9151.0
# reward======================= 10.0
# Steps ======================= 8775.0
# reward======================= 10.0
# Steps ======================= 9163.0
# reward======================= 10.0
# Steps ======================= 8524.0
# reward======================= 10.0
# Steps ======================= 8632.0
# reward======================= 10.0
# Steps ======================= 9972.0
# reward======================= 10.0
# Steps ======================= 8885.0
# reward======================= 10.0
# Steps ======================= 9762.0
# reward======================= 10.0
# Steps ======================= 9986.0
# reward======================= 10.0
# Steps ======================= 8616.0
# reward======================= 10.0
# Steps ======================= 8984.0
# reward======================= 10.0
# Steps ======================= 9331.0
# reward======================= 10.0
# Steps ======================= 9283.0
# reward======================= 10.0
# Steps ======================= 8793.0
# reward======================= 10.0
# Steps ======================= 9264.0
# reward======================= 10.0
# Steps ======================= 9619.0
# reward======================= 10.0
# Steps ======================= 9375.0
# reward======================= 10.0
# Steps ======================= 8439.0
# reward======================= 10.0
# Steps ======================= 8817.0
# reward======================= 10.0
# Steps ======================= 9374.0
# reward======================= 10.0
# Steps ======================= 8954.0
# reward======================= 10.0
# Steps ======================= 8726.0
# reward======================= 10.0
# Steps ======================= 9531.0
# reward======================= 10.0
# Steps ======================= 8897.0
# reward======================= 10.0
# Steps ======================= 9330.0
# reward======================= 10.0
# Steps ======================= 8863.0
# reward======================= 10.0
# Steps ======================= 7999.0
# reward======================= 10.0
# Steps ======================= 9508.0
# reward======================= 10.0
# Steps ======================= 8782.0
# reward======================= 10.0
# Steps ======================= 8406.0
# reward======================= 10.0
# Steps ======================= 8994.0
# reward======================= 10.0
# Steps ======================= 9438.0
# reward======================= 10.0
# Steps ======================= 8798.0
# reward======================= 10.0
# Steps ======================= 9242.0
# reward======================= 10.0
# Steps ======================= 10275.0
# reward======================= 10.0
# Steps ======================= 9288.0
# reward======================= 10.0
# Steps ======================= 9131.0
# reward======================= 10.0
# Steps ======================= 8563.0
# reward======================= 10.0
# Steps ======================= 8949.0
# reward======================= 10.0
# Steps ======================= 4523.0
# reward======================= 10.0
# Steps ======================= 4178.0
# reward======================= 10.0
# Steps ======================= 4095.0
# reward======================= 10.0
# Steps ======================= 4456.0
# reward======================= 10.0
# Steps ======================= 4767.0
# reward======================= 10.0
# Steps ======================= 4430.0
# reward======================= 10.0
# Steps ======================= 3944.0
# reward======================= 10.0
# Steps ======================= 4094.0
# reward======================= 10.0
# Steps ======================= 4010.0
# reward======================= 10.0
# Steps ======================= 3982.0
# reward======================= 10.0
# Steps ======================= 4223.0
# reward======================= 10.0
# Steps ======================= 4152.0
# reward======================= 10.0
# Steps ======================= 3761.0
# reward======================= 10.0
# Steps ======================= 4505.0
# reward======================= 10.0
# Steps ======================= 3828.0
# reward======================= 10.0
# Steps ======================= 4589.0
# reward======================= 10.0
# Steps ======================= 4042.0
# reward======================= 10.0
# Steps ======================= 4309.0
# reward======================= 10.0
# Steps ======================= 4489.0
# reward======================= 10.0
# Steps ======================= 3842.0
# reward======================= 10.0
# Steps ======================= 4777.0
# reward======================= 10.0
# Steps ======================= 5435.0
# reward======================= 10.0
# Steps ======================= 5140.0
# reward======================= 10.0
# Steps ======================= 5059.0
# reward======================= 10.0
# Steps ======================= 5650.0
# reward======================= 10.0
# Steps ======================= 5090.0
# reward======================= 10.0
# Steps ======================= 4970.0
# reward======================= 10.0
# Steps ======================= 4967.0
# reward======================= 10.0
# Steps ======================= 5253.0
# reward======================= 10.0
# Steps ======================= 5104.0
# reward======================= 10.0
# Steps ======================= 5239.0
# reward======================= 10.0
# Steps ======================= 5216.0
# reward======================= 10.0
# Steps ======================= 5072.0
# reward======================= 10.0
# Steps ======================= 4976.0
# reward======================= 10.0
# Steps ======================= 5160.0
# reward======================= 10.0
# Steps ======================= 5523.0
# reward======================= 10.0
# Steps ======================= 4937.0
# reward======================= 10.0
# Steps ======================= 5247.0
# reward======================= 10.0
# Steps ======================= 5292.0
# reward======================= 10.0
# Steps ======================= 4947.0
# reward======================= 10.0
# Steps ======================= 6426.0
# reward======================= 10.0
# Steps ======================= 6480.0
# reward======================= 10.0
# Steps ======================= 6741.0
# reward======================= 10.0
# Steps ======================= 6218.0
# reward======================= 10.0
# Steps ======================= 6130.0
# reward======================= 10.0
# Steps ======================= 6157.0
# reward======================= 10.0
# Steps ======================= 6780.0
# reward======================= 10.0
# Steps ======================= 6619.0
# reward======================= 10.0
# Steps ======================= 6610.0
# reward======================= 10.0
# Steps ======================= 6325.0
# reward======================= 10.0
# Steps ======================= 6601.0
# reward======================= 10.0
# Steps ======================= 6501.0
# reward======================= 10.0
# Steps ======================= 7192.0
# reward======================= 10.0
# Steps ======================= 6544.0
# reward======================= 10.0
# Steps ======================= 6636.0
# reward======================= 10.0
# Steps ======================= 6960.0
# reward======================= 10.0
# Steps ======================= 6611.0
# reward======================= 10.0
# Steps ======================= 6349.0
# reward======================= 10.0
# Steps ======================= 6551.0
# reward======================= 10.0
# Steps ======================= 6691.0
# reward======================= 10.0
# Steps ======================= 8868.0
# reward======================= 10.0
# Steps ======================= 9638.0
# reward======================= 10.0
# Steps ======================= 10023.0
# reward======================= 10.0
# Steps ======================= 9672.0
# reward======================= 10.0
# Steps ======================= 9444.0
# reward======================= 10.0
# Steps ======================= 8668.0
# reward======================= 10.0
# Steps ======================= 7855.0
# reward======================= 10.0
# Steps ======================= 8376.0
# reward======================= 10.0
# Steps ======================= 8500.0
# reward======================= 10.0
# Steps ======================= 8744.0
# reward======================= 10.0
# Steps ======================= 9221.0
# reward======================= 10.0
# Steps ======================= 9973.0
# reward======================= 10.0
# Steps ======================= 10580.0
# reward======================= 10.0
# Steps ======================= 9057.0
# reward======================= 10.0
# Steps ======================= 10385.0
# reward======================= 10.0
# Steps ======================= 9359.0
# reward======================= 10.0
# Steps ======================= 9337.0
# reward======================= 10.0
# Steps ======================= 8932.0
# reward======================= 10.0
# Steps ======================= 9395.0
# reward======================= 10.0
# Steps ======================= 8944.0
# reward======================= 10.0
# Steps ======================= 9689.0
# reward======================= 10.0
# Steps ======================= 9160.0
# reward======================= 10.0
# Steps ======================= 8884.0
# reward======================= 10.0
# Steps ======================= 8677.0
# reward======================= 10.0
# Steps ======================= 8752.0
# reward======================= 10.0
# Steps ======================= 8136.0
# reward======================= 10.0
# Steps ======================= 9469.0
# reward======================= 10.0
# Steps ======================= 8227.0
# reward======================= 10.0
# Steps ======================= 9950.0
# reward======================= 10.0
# Steps ======================= 9777.0
# reward======================= 10.0
# Steps ======================= 8449.0
# reward======================= 10.0
# Steps ======================= 8179.0
# reward======================= 10.0
# Steps ======================= 10064.0
# reward======================= 10.0
# Steps ======================= 9056.0
# reward======================= 10.0
# Steps ======================= 9517.0
# reward======================= 10.0
# Steps ======================= 9698.0
# reward======================= 10.0
# Steps ======================= 9148.0
# reward======================= 10.0
# Steps ======================= 9641.0
# reward======================= 10.0
# Steps ======================= 9726.0
# reward======================= 10.0
# Steps ======================= 9103.0
# reward======================= 10.0

# %%
def main():    # parameters
    gamma = 1000
    alpha = 0.01
    epsilon = 0.5
    episodes = 100
    
    lambda_ = [0.1, 0.5]
    
    env = gym.make('gym_pdw:pdw-v0')
    fa = FA_SARSA_lambda()
    for i in range(len(lambda_)):
        avg_reward, steps, theta = fa.fa_sarsa_lambda(gamma, alpha, epsilon, episodes, env, lambda_[i])
        fa.plot_fa_sarsa_lambda(avg_reward, steps, episodes)
#     plot_policy(goal_pos,Q)    

main()
# Out:
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in multiply
#   # Remove the CWD from sys.path while we load stuff.
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in matmul
#
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:99: RuntimeWarning: overflow encountered in multiply
# Steps ======================= 4046.0
# reward======================= 10.0
# Steps ======================= 4029.0
# reward======================= 10.0
# Steps ======================= 3942.0
# reward======================= 10.0
# Steps ======================= 4406.0
# reward======================= 10.0
# Steps ======================= 3845.0
# reward======================= 10.0
# Steps ======================= 4082.0
# reward======================= 10.0
# Steps ======================= 4177.0
# reward======================= 10.0
# Steps ======================= 4236.0
# reward======================= 10.0
# Steps ======================= 3952.0
# reward======================= 10.0
# Steps ======================= 4119.0
# reward======================= 10.0
# Steps ======================= 4135.0
# reward======================= 10.0
# Steps ======================= 4388.0
# reward======================= 10.0
# Steps ======================= 3957.0
# reward======================= 10.0
# Steps ======================= 3981.0
# reward======================= 10.0
# Steps ======================= 4168.0
# reward======================= 10.0
# Steps ======================= 4070.0
# reward======================= 10.0
# Steps ======================= 3903.0
# reward======================= 10.0
# Steps ======================= 4474.0
# reward======================= 10.0
# Steps ======================= 4332.0
# reward======================= 10.0
# Steps ======================= 3851.0
# reward======================= 10.0
# Steps ======================= 4723.0
# reward======================= 10.0
# Steps ======================= 4670.0
# reward======================= 10.0
# Steps ======================= 5153.0
# reward======================= 10.0
# Steps ======================= 5050.0
# reward======================= 10.0
# Steps ======================= 5176.0
# reward======================= 10.0
# Steps ======================= 5305.0
# reward======================= 10.0
# Steps ======================= 5870.0
# reward======================= 10.0
# Steps ======================= 5508.0
# reward======================= 10.0
# Steps ======================= 5318.0
# reward======================= 10.0
# Steps ======================= 5290.0
# reward======================= 10.0
# Steps ======================= 5006.0
# reward======================= 10.0
# Steps ======================= 5090.0
# reward======================= 10.0
# Steps ======================= 4773.0
# reward======================= 10.0
# Steps ======================= 5339.0
# reward======================= 10.0
# Steps ======================= 5160.0
# reward======================= 10.0
# Steps ======================= 5589.0
# reward======================= 10.0
# Steps ======================= 5240.0
# reward======================= 10.0
# Steps ======================= 5352.0
# reward======================= 10.0
# Steps ======================= 4865.0
# reward======================= 10.0
# Steps ======================= 5220.0
# reward======================= 10.0
# Steps ======================= 5811.0
# reward======================= 10.0
# Steps ======================= 6533.0
# reward======================= 10.0
# Steps ======================= 6611.0
# reward======================= 10.0
# Steps ======================= 6966.0
# reward======================= 10.0
# Steps ======================= 6463.0
# reward======================= 10.0
# Steps ======================= 6229.0
# reward======================= 10.0
# Steps ======================= 6467.0
# reward======================= 10.0
# Steps ======================= 6718.0
# reward======================= 10.0
# Steps ======================= 6376.0
# reward======================= 10.0
# Steps ======================= 6114.0
# reward======================= 10.0
# Steps ======================= 6800.0
# reward======================= 10.0
# Steps ======================= 7342.0
# reward======================= 10.0
# Steps ======================= 6073.0
# reward======================= 10.0
# Steps ======================= 6907.0
# reward======================= 10.0
# Steps ======================= 6457.0
# reward======================= 10.0
# Steps ======================= 6675.0
# reward======================= 10.0
# Steps ======================= 6829.0
# reward======================= 10.0
# Steps ======================= 6568.0
# reward======================= 10.0
# Steps ======================= 7152.0
# reward======================= 10.0
# Steps ======================= 6045.0
# reward======================= 10.0
# Steps ======================= 9659.0
# reward======================= 10.0
# Steps ======================= 9223.0
# reward======================= 10.0
# Steps ======================= 10006.0
# reward======================= 10.0
# Steps ======================= 8662.0
# reward======================= 10.0
# Steps ======================= 8654.0
# reward======================= 10.0
# Steps ======================= 9174.0
# reward======================= 10.0
# Steps ======================= 8924.0
# reward======================= 10.0
# Steps ======================= 8629.0
# reward======================= 10.0
# Steps ======================= 8266.0
# reward======================= 10.0
# Steps ======================= 8855.0
# reward======================= 10.0
# Steps ======================= 9414.0
# reward======================= 10.0
# Steps ======================= 8234.0
# reward======================= 10.0
# Steps ======================= 9296.0
# reward======================= 10.0
# Steps ======================= 9873.0
# reward======================= 10.0
# Steps ======================= 9089.0
# reward======================= 10.0
# Steps ======================= 8532.0
# reward======================= 10.0
# Steps ======================= 8635.0
# reward======================= 10.0
# Steps ======================= 9186.0
# reward======================= 10.0
# Steps ======================= 10146.0
# reward======================= 10.0
# Steps ======================= 9729.0
# reward======================= 10.0
# Steps ======================= 9075.0
# reward======================= 10.0
# Steps ======================= 8368.0
# reward======================= 10.0
# Steps ======================= 8071.0
# reward======================= 10.0
# Steps ======================= 8917.0
# reward======================= 10.0
# Steps ======================= 9530.0
# reward======================= 10.0
# Steps ======================= 9540.0
# reward======================= 10.0
# Steps ======================= 9001.0
# reward======================= 10.0
# Steps ======================= 8764.0
# reward======================= 10.0
# Steps ======================= 9139.0
# reward======================= 10.0
# Steps ======================= 9171.0
# reward======================= 10.0
# Steps ======================= 9616.0
# reward======================= 10.0
# Steps ======================= 9125.0
# reward======================= 10.0
# Steps ======================= 8754.0
# reward======================= 10.0
# Steps ======================= 9379.0
# reward======================= 10.0
# Steps ======================= 9553.0
# reward======================= 10.0
# Steps ======================= 8523.0
# reward======================= 10.0
# Steps ======================= 9670.0
# reward======================= 10.0
# Steps ======================= 9442.0
# reward======================= 10.0
# Steps ======================= 8388.0
# reward======================= 10.0
# Steps ======================= 9994.0
# reward======================= 10.0
# /home/saivinay/.local/lib/python3.5/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in matmul
# Steps ======================= 3974.0
# reward======================= 10.0
# Steps ======================= 3896.0
# reward======================= 10.0
# Steps ======================= 4359.0
# reward======================= 10.0
# Steps ======================= 4384.0
# reward======================= 10.0
# Steps ======================= 4099.0
# reward======================= 10.0
# Steps ======================= 4213.0
# reward======================= 10.0
# Steps ======================= 4274.0
# reward======================= 10.0
# Steps ======================= 3945.0
# reward======================= 10.0
# Steps ======================= 4015.0
# reward======================= 10.0
# Steps ======================= 4187.0
# reward======================= 10.0
# Steps ======================= 3972.0
# reward======================= 10.0
# Steps ======================= 4396.0
# reward======================= 10.0
# Steps ======================= 4443.0
# reward======================= 10.0
# Steps ======================= 3998.0
# reward======================= 10.0
# Steps ======================= 4325.0
# reward======================= 10.0
# Steps ======================= 4189.0
# reward======================= 10.0
# Steps ======================= 4224.0
# reward======================= 10.0
# Steps ======================= 4418.0
# reward======================= 10.0
# Steps ======================= 4119.0
# reward======================= 10.0
# Steps ======================= 4308.0
# reward======================= 10.0
# Steps ======================= 5077.0
# reward======================= 10.0
# Steps ======================= 4902.0
# reward======================= 10.0
# Steps ======================= 5675.0
# reward======================= 10.0
# Steps ======================= 4772.0
# reward======================= 10.0
# Steps ======================= 5103.0
# reward======================= 10.0
# Steps ======================= 5349.0
# reward======================= 10.0
# Steps ======================= 4956.0
# reward======================= 10.0
# Steps ======================= 4953.0
# reward======================= 10.0
# Steps ======================= 4540.0
# reward======================= 10.0
# Steps ======================= 5017.0
# reward======================= 10.0
# Steps ======================= 5678.0
# reward======================= 10.0
# Steps ======================= 5120.0
# reward======================= 10.0
# Steps ======================= 4962.0
# reward======================= 10.0
# Steps ======================= 5303.0
# reward======================= 10.0
# Steps ======================= 5430.0
# reward======================= 10.0
# Steps ======================= 5028.0
# reward======================= 10.0
# Steps ======================= 4810.0
# reward======================= 10.0
# Steps ======================= 4756.0
# reward======================= 10.0
# Steps ======================= 4738.0
# reward======================= 10.0
# Steps ======================= 4887.0
# reward======================= 10.0
# Steps ======================= 6173.0
# reward======================= 10.0
# Steps ======================= 6956.0
# reward======================= 10.0
# Steps ======================= 6699.0
# reward======================= 10.0
# Steps ======================= 6732.0
# reward======================= 10.0
# Steps ======================= 7036.0
# reward======================= 10.0
# Steps ======================= 6708.0
# reward======================= 10.0
# Steps ======================= 6707.0
# reward======================= 10.0
# Steps ======================= 6529.0
# reward======================= 10.0
# Steps ======================= 6286.0
# reward======================= 10.0
# Steps ======================= 6273.0
# reward======================= 10.0
# Steps ======================= 6540.0
# reward======================= 10.0
# Steps ======================= 6888.0
# reward======================= 10.0
# Steps ======================= 6565.0
# reward======================= 10.0
# Steps ======================= 6489.0
# reward======================= 10.0
# Steps ======================= 6921.0
# reward======================= 10.0
# Steps ======================= 6552.0
# reward======================= 10.0
# Steps ======================= 6564.0
# reward======================= 10.0
# Steps ======================= 6523.0
# reward======================= 10.0
# Steps ======================= 6412.0
# reward======================= 10.0
# Steps ======================= 6553.0
# reward======================= 10.0
# Steps ======================= 8375.0
# reward======================= 10.0
# Steps ======================= 8566.0
# reward======================= 10.0
# Steps ======================= 9872.0
# reward======================= 10.0
# Steps ======================= 9361.0
# reward======================= 10.0
# Steps ======================= 8894.0
# reward======================= 10.0
# Steps ======================= 9021.0
# reward======================= 10.0
# Steps ======================= 8747.0
# reward======================= 10.0
# Steps ======================= 9610.0
# reward======================= 10.0
# Steps ======================= 8384.0
# reward======================= 10.0
# Steps ======================= 9166.0
# reward======================= 10.0
# Steps ======================= 9204.0
# reward======================= 10.0
# Steps ======================= 9912.0
# reward======================= 10.0
# Steps ======================= 9153.0
# reward======================= 10.0
# Steps ======================= 8573.0
# reward======================= 10.0
# Steps ======================= 8262.0
# reward======================= 10.0
# Steps ======================= 9154.0
# reward======================= 10.0
# Steps ======================= 9320.0
# reward======================= 10.0
# Steps ======================= 8985.0
# reward======================= 10.0
# Steps ======================= 9241.0
# reward======================= 10.0
# Steps ======================= 8671.0
# reward======================= 10.0
# Steps ======================= 8873.0
# reward======================= 10.0
# Steps ======================= 9371.0
# reward======================= 10.0
# Steps ======================= 8934.0
# reward======================= 10.0
# Steps ======================= 8957.0
# reward======================= 10.0
# Steps ======================= 9198.0
# reward======================= 10.0
# Steps ======================= 8679.0
# reward======================= 10.0
# Steps ======================= 9876.0
# reward======================= 10.0
# Steps ======================= 9194.0
# reward======================= 10.0
# Steps ======================= 8039.0
# reward======================= 10.0
# Steps ======================= 9119.0
# reward======================= 10.0
# Steps ======================= 8853.0
# reward======================= 10.0
# Steps ======================= 9588.0
# reward======================= 10.0
# Steps ======================= 8143.0
# reward======================= 10.0
# Steps ======================= 8977.0
# reward======================= 10.0
# Steps ======================= 9265.0
# reward======================= 10.0
# Steps ======================= 8434.0
# reward======================= 10.0
# Steps ======================= 8790.0
# reward======================= 10.0
# Steps ======================= 8933.0
# reward======================= 10.0
# Steps ======================= 9147.0
# reward======================= 10.0
# Steps ======================= 9241.0
# reward======================= 10.0

# %%
def main():    # parameters
    gamma = 1
    alpha = 0.01
    epsilon = 0.5
    episodes = 100
    
    lambda_ = [0.1, 0.5]
    
    env = gym.make('gym_pdw:pdw-v0')
    fa = FA_SARSA_lambda()
    for i in range(len(lambda_)):
        avg_reward, steps, theta = fa.fa_sarsa_lambda(gamma, alpha, epsilon, episodes, env, lambda_[i])
        fa.plot_fa_sarsa_lambda(avg_reward, steps, episodes)
#     plot_policy(goal_pos,Q)    

main()
# Out:
# ------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-21-7f523f7a5f56> in <module>
#      14 #     plot_policy(goal_pos,Q)
#      15
# ---> 16 main()
#
# <ipython-input-21-7f523f7a5f56> in main()
#      10     fa = FA_SARSA_lambda()
#      11     for i in range(len(lambda_)):
# ---> 12         avg_reward, steps, theta = fa.fa_sarsa_lambda(gamma, alpha, epsilon, episodes, env, lambda_[i])
#      13         fa.plot_fa_sarsa_lambda(avg_reward, steps, episodes)
#      14 #     plot_policy(goal_pos,Q)
#
# <ipython-input-14-f15c3f23e384> in fa_sarsa_lambda(self, gamma, alpha, epsilon, episodes, env, lambda_)
#      92                 E += 1
#      93 #                 print("==========")
# ---> 94                 next_state, reward = env.large_step(new_grid, curr_state, curr_action)
#      95                 next_action = self.select_action(epsilon, next_state, theta, env)
#      96
#
# ~/Documents/computer-science/Reinforcement-Learning-CS6900/assignments/programming/assignment_2/gym-pdw/gym_pdw/envs/pdw_env.py in large_step(self, new_grid, curr_state, action)
#     222     def large_step(self, new_grid, curr_state, action):
#     223         # Return the postion,reward after performing an action.
# --> 224         action = self.actual_action(action)
#     225
#     226         # Because of wind effect
#
# ~/Documents/computer-science/Reinforcement-Learning-CS6900/assignments/programming/assignment_2/gym-pdw/gym_pdw/envs/pdw_env.py in actual_action(self, selected_action)
#      99
#     100     def step(self, curr_state, action):
# --> 101         # Return the postion,reward after performing an action.
#     102
#     103         # Select the action by considering stochastic nature after selecting an action
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ~/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims, initial)
#    2770     """
#    2771     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out, keepdims=keepdims,
# -> 2772                           initial=initial)
#    2773
#    2774
#
# ~/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      68
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      72
#
# ~/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py in <dictcomp>(.0)
#      68
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      72
#
# KeyboardInterrupt:

# %%
# Part B)

'''
δt=Rt+1+γˆq(St+1,At+1,w)−ˆq(St,At,w)
Et=γλEt−1+x(S,A)
∆w=αδtEt
'''
# Out:
# '\nδt=Rt+1+γˆq(St+1,At+1,w)−ˆq(St,At,w)\nEt=γλEt−1+x(S,A)\n∆w=αδtEt\n'

# %%
env = gym.make('gym_pdw:pdw-v0')

# %%
gr = env.large_puddle_world(10,100,'A')

# %%
gr.shape
# Out:
# ------------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-9-50b3cd338afb> in <module>
# ----> 1 gr.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
# import sys
# np.set_printoptions(threshold=sys.maxsize)
# gr
